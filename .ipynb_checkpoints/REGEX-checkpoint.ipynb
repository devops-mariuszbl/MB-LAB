# %% [markdown]
# Przykład 1

# %%
import re

# %%
line = '30 acd3.b2c6.aac9 FastEthernet0/1'

# %%
match = re.search('aaa', 'aaabbbaaadsdsaaadfd')

# %%
if match:
    print(match.group())
# Out:
# aaa

# %% [markdown]
# Przykład 2

# %%
import re

# %%
intf_ip = '''Gi0/0/0.705 10.103.17.5 YES NVRAM up up
Gi0/0/0.900 86.121.75.31 YES NVRAM up up
Gi0/0/0.911 10.200.101.242 YES NVRAM up up
Gi0/0/0.7000 unassigned YES unset up up
'''

# %%
match = re.search("\d+\.\d+\.\d+\.\d+", intf_ip)
if match:
    print(match.group())
# Out:
# 10.103.17.5

# %% [markdown]
# Przykład 3

# %%
import re

# %%
log_msg = 'Dec 20 12:11:47.417: %LINK-3-UPDOWN: Interface GigabitEthernet0/0/4, changed state to down'

# %%
match = re.search("(\w+\s\d+\s\S+): Interface (\S+)", log_msg)
if match:
    print(match.group())

# %%
! DIR
# Out:
#  Volume in drive E is DATA1-200GB
#  Volume Serial Number is 464D-71E0
#
#  Directory of E:\_git\_git-devops-mariuszbl\MB-LAB
#
# 2021-06-09  10:20    <DIR>          .
# 2021-06-09  10:20    <DIR>          ..
# 2021-06-09  09:15    <DIR>          .ipynb_checkpoints
# 2021-06-09  09:11               858 PANDAS.ipynb
# 2021-06-09  10:20             3˙499 REGEX.ipynb
#                2 File(s)          4˙357 bytes
#                3 Dir(s)  142˙564˙003˙840 bytes free
