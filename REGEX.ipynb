# %% [markdown]
# Przykład 1 - ciągi znaków

# %%
import re

# %%
line = '30 acd3.b2c6.aac9 FastEthernet0/1'

# %%
match = re.search('aaa', 'aaabbbaaadsdsaaadfd')

# %%
if match:
    print(match.group())
# Out:
# aaa

# %% [markdown]
# Przykład 2 - konkretny tekst liczbowo znakowy

# %%
import re

# %%
intf_ip = '''Gi0/0/0.705 10.103.17.5 YES NVRAM up up
Gi0/0/0.900 86.121.75.31 YES NVRAM up up
Gi0/0/0.911 10.200.101.242 YES NVRAM up up
Gi0/0/0.7000 unassigned YES unset up up
'''

# %%
match = re.search("\d+\.\d+\.\d+\.\d+", intf_ip)
if match:
    print(match.group())
# Out:
# 10.103.17.5

# %% [markdown]
# Przykład 3 - grupy wyrażeń

# %%
import re

# %%
log_msg = 'Dec 20 12:11:47.417: %LINK-3-UPDOWN: Interface GigabitEthernet0/0/4, changed state to down'

# %%
match = re.search("(\w+\s\d+\s\S+):(\s\S+): Interface (\S+), changed state to (\S+)", log_msg)
if match:
    print(match.groups())
# Out:
# ('Dec 20 12:11:47.417', ' %LINK-3-UPDOWN', 'GigabitEthernet0/0/4', 'down')

# %% [markdown]
# Przykład 4 - nazwane grupy regexowe

# %%
import re

# %%
log_msg = 'Dec 20 12:11:47.417: %LINK-3-UPDOWN: Interface GigabitEthernet0/0/4, changed state to down'

# %%
match = re.search("(?P<TIMESTAMP>\w+\s\d+\s\S+):\s(?P<EVENT>\S+): Interface (?P<INTF>\S+), changed state to (?P<STATE>\S+)", log_msg)
if match:
    print(match.groups())
# Out:
# ('Dec 20 12:11:47.417', '%LINK-3-UPDOWN', 'GigabitEthernet0/0/4', 'down')

# %%
# ?P<"NAME">

# %%
! DIR /B/S
# Out:
# E:\_git\_git-devops-mariuszbl\MB-LAB\.ipynb_checkpoints
# E:\_git\_git-devops-mariuszbl\MB-LAB\PANDAS.ipynb
# E:\_git\_git-devops-mariuszbl\MB-LAB\REGEX.ipynb
# E:\_git\_git-devops-mariuszbl\MB-LAB\.ipynb_checkpoints\REGEX-checkpoint.ipynb
# E:\_git\_git-devops-mariuszbl\MB-LAB\.ipynb_checkpoints\Untitled-checkpoint.ipynb
